# %% [markdown]
# # Rough notebook for rough work - ignore for grading or other purposes

# %%
from Crypto.Util.Padding import pad, unpad
import secrets

# %%
cookie = "6c222a3c3002af9dcb1acb817983a06844b99e4ca9fdc92cf1d63f1516b79f8c2ad2cae0224bbd88a282f347b20945a3c446aa197c3675d2a492ee9bd7c40b2e"

# %%
cookie = "9b5747e9ca8bdfd9afd8b4532d1118a2f505787321fb8f5a7499ac1d67c7c5edb6369c3dafbdf6b4425d08dfb664a4d571f6c7f7ab829537cb05ebde07961734"

# %%
text = "22133210"
pad(text.encode(), 4)
# Out:
# b'22133210\x04\x04\x04\x04'

# %%
iv = secrets.token_bytes(16)

print(iv)
print(len(iv) , "bytes")
print(len(iv)*8, "bits")
print(len(iv)*2, "hexes")
print("blocksize is 16 bytes / 128 bits")
# Out:
# b'u\x9c\xed\x154\xf5k\xf2\xf6\xa8I)\x81\x10\xaf\xa3'
# 16 bytes
# 128 bits
# 32 hexes
# blocksize is 16 bytes / 128 bits

# %%
iv_bytearray = bytearray(iv)
print(iv_bytearray)

iv_bytearray[0] = 255

print(iv_bytearray)
# Out:
# bytearray(b'u\x9c\xed\x154\xf5k\xf2\xf6\xa8I)\x81\x10\xaf\xa3')
# bytearray(b'\xff\x9c\xed\x154\xf5k\xf2\xf6\xa8I)\x81\x10\xaf\xa3')

# %%
a = bytes(b'0123456789')
b = bytearray(a)
print(b)
c = bytes(b)
print(c)
print(b[2:])

print(b[:2])
print(b[2:])
# Out:
# bytearray(b'0123456789')
# b'0123456789'
# bytearray(b'23456789')
# bytearray(b'01')
# bytearray(b'23456789')

# %%
def replace_byte(byteString: bytes, idx: int, newNumber:int ) -> bytes :
    myByteArray = bytearray(byteString)
    myByteArray[idx] = newNumber
    new_bytes = bytes(myByteArray)
    return new_bytes


iv= replace_byte(iv, 0, 0)
print(iv)
# Out:
# b'\x00\x9c\xed\x154\xf5k\xf2\xf6\xa8I)\x81\x10\xaf\xa3'

# %%
i =255
i_byte = i.to_bytes()
print(i_byte)
# Out:
# b'\xff'

# %%
iv = bytes(b'0'*16)
iv2 = bytes(16)
print(iv2)
print(iv)
print(bytearray(iv))
print(len(iv))

modified_ct = bytearray(8)
print(modified_ct)
# Out:
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# b'0000000000000000'
# bytearray(b'0000000000000000')
# 16
# bytearray(b'\x00\x00\x00\x00\x00\x00\x00\x00')

# %%
15*3
# Out:
# 45

# %%
16*4
# Out:
# 64

# %%
15*2
# Out:
# 30

# %%
(16*2) +15
# Out:
# 47

# %%
key_stream = bytearray(64)
    # key_stream[(current_blocknumber*(blocklength+1)) -nth_byte_from_end- 1] = nth_plus_15th_keystream.to_bytes()
key_stream[63] = 2

print(key_stream)
# Out:
# bytearray(b'')

# %%
value = bytes([0x9])  # This creates a bytes object: b'\x01'
int_value = int.from_bytes(value, 'big')  # Convert to int

print(int_value)
# Out:
# 9

# %%
print(len(b'You never figure out that "<redacted>". :)\x06\x06\x06\x06\x06\x06'))
# Out:
# 48

# %%
for j in range(1,1):
    print(j)

# %%
secret = "I must use authenticated encryption since ..."
print(len(secret))
# Out:
# 45

# %%
secret_local = "<redacted>"
print(len(secret_local))

candidate_key_local = "BBB<redacted>BBB"
# Out:
# 10

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad

# %%
plaintext = f"{secret_local}".encode()

token = encrypt(plaintext)

# %%
import secrets

forged_ct_length = 64
blocklength = 16

original_token = bytes(forged_ct_length)
ct_x = bytes(forged_ct_length)
key_stream = bytes(blocklength)

#sample random last CT
c_2 = secrets.token_bytes(16)
original_token = bytearray(original_token)
original_token[16*3:] = c_2
original_token = bytes(original_token)

print(original_token)
# Out:
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xa8\xc2\xc1\xff1\x1b\xa4?\xd7\xdd\x03\xb4\x15\xb5\x10\xdf'

# %%
for i in range(3, 0, -1):
    print(i)
# Out:
# 3
# 2
# 1

# %%
secret_server = b"I must use authenticated encryption since ..." #we found
secret_server+= b" plain CBC is not secure!" # we found

print(secret_server)
# Out:
# b'I must use authenticated encryption since ... plain CBC is not secure!'

# %%
final_quote = "flag{0MG_wh0_d15abl3d_C0NST4NT_T1M3_ERR0R5}" #yayyyyyy
